# %% [raw]
# ---
# title: Unidad 3
# ---

# %% [markdown]
# ## Programando
#
# ¿Por qué el siguiente bloque muestra solo un número como salida?

# %%
for i in range(3):
    print(i)
    break
# Out:
# 0
